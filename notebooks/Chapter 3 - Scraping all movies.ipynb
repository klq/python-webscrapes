# %%
# Python 2 & 3 Compatibility
from __future__ import print_function, division

# %% [markdown]
# # Chapter 3 - Scraping all movies - loop magic

# %% [markdown]
# ## TODO:
# Summary:  In this notebook, we will assemble pieces together and put all the scraping code into a loop to go through all 200 movies automatically
#
# We'll also save our scraped information in a data frame and answer some questions.

# %%
import requests
from bs4 import BeautifulSoup

import re
import time
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-32-7106bdac4cc9> in <module>()
#       5 import time
#       6 import pandas as pd
# ----> 7 import matplotlib.pyplot as plt
#       8 get_ipython().magic('matplotlib inline')
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
# Let's see what our top 5 movies are
# !head -n5 ../data/movie_urls.txt
# Out:
# /movies/?id=gonewiththewind.htm
# /movies/?id=starwars4.htm
# /movies/?id=soundofmusic.htm
# /movies/?id=et.htm
# /movies/?id=titanic.htm

# %%
base_url = 'http://www.boxofficemojo.com'

# %%
movie_urls = pd.read_csv('../data/movie_urls.txt', names = ['url'], header=None)

# %%
movie_urls.head()
# Out:
#                                url
# 0  /movies/?id=gonewiththewind.htm
# 1        /movies/?id=starwars4.htm
# 2     /movies/?id=soundofmusic.htm
# 3               /movies/?id=et.htm
# 4          /movies/?id=titanic.htm

# %%
def get_movie_value(soup, field_name):
    '''Grab a value from boxofficemojo HTML
    
    Takes a string attribute of a movie on the page and
    returns the string in the next sibling object
    (the value for that attribute)
    or None if nothing is found.
    '''
    obj = soup.find(text=re.compile(field_name))
    if not obj: 
        return None
    # this works for most of the values
    next_sibling = obj.findNextSibling()
    if next_sibling:
        return next_sibling.text 
    else:
        return None

# %%
# If you want to scrape all movies, uncomment this section
##

# headers = ['movie title', 'domestic total gross','genre',
#            'release date', 'runtime (mins)', 'rating']

# movie_data = []


# for movie_url in movie_urls['url']:
#     response = requests.get(base_url + movie_url + '&adjust_yr=2017')
#     if response.ok:
#         soup = BeautifulSoup(response.text,'html.parser')
                
#         # Scrape all fields for each movie
#         #######################
#         # movie title
#         title = soup.find('title').string.split('(')[0].strip()        
#         # domestic total gross
#         dtg = get_movie_value(soup,'Domestic Total')        
#         # genre
#         genre = get_movie_value(soup,'Genre:')   
#         # release date
#         release_date = get_movie_value(soup,'Release Date')
#         # runtime
#         runtime = get_movie_value(soup,'Runtime')
#         # rating
#         rating = get_movie_value(soup,'MPAA Rating')
        
        
#         # store it in a movie object
#         movie_dict = dict(zip(headers, [title,
#                                 dtg,
#                                 genre,
#                                 release_date,
#                                 runtime,
#                                 rating]))
#         movie_data.append(movie_dict)
        
#         time.sleep(0.5)
#     else:
#         print("Request errored out with code {}".format(response.status_code))

# %%
len(movie_data)

# %%
# Save our precious data into a file
pd.DataFrame(movie_data).to_csv('../data/alltime_movies200.csv', index=False)

# %%
# Let's use our old trick to peek at the output data
# !head -n5 ../data/alltime_movies200.csv
# Out:
# domestic total gross,genre,movie title,rating,release date,runtime (mins)
# "$1,768,000,000",Historical Epic,Gone with the Wind,G,"December 15, 1939",3 hrs. 58 min.
# "$1,261,768,700",Sci-Fi Fantasy,Star Wars,PG,"May 25, 1977",2 hrs. 1 min.
# "$1,258,951,900",Musical,The Sound of Music,G,"March 2, 1965",2 hrs. 54 min.
# "$1,099,155,300",Family Adventure,E.T.: The Extra-Terrestrial,PG,"June 11, 1982",1 hrs. 57 min.

# %% [markdown]
# ## We are almost done. But remember how we re-formatted the data in the last section? Let's do that to the dataframe too. We'll use a series of  `.map()` functions to directly operate on the columns

# %%
df = pd.read_csv('../data/alltime_movies200.csv')

# %%
df.head()
# Out:
#   domestic total gross             genre                  movie title rating  \
# 0       $1,768,000,000   Historical Epic           Gone with the Wind      G
# 1       $1,261,768,700    Sci-Fi Fantasy                    Star Wars     PG
# 2       $1,258,951,900           Musical           The Sound of Music      G
# 3       $1,099,155,300  Family Adventure  E.T.: The Extra-Terrestrial     PG
# 4       $1,134,577,600           Romance                      Titanic  PG-13
#
#         release date  runtime (mins)
# 0  December 15, 1939  3 hrs. 58 min.
# 1       May 25, 1977   2 hrs. 1 min.
# 2      March 2, 1965  2 hrs. 54 min.
# 3      June 11, 1982  1 hrs. 57 min.
# 4  December 19, 1997  3 hrs. 14 min.

# %%
# convert domestic total gross into numbers
df['domestic total gross'] = df['domestic total gross'].map(lambda x: int(x.replace('$','').replace(',','')))

# %%
# convert release date into datetime
df['release date'] = pd.to_datetime(df['release date'])

# %%
def runtime_to_minutes(runtimestring):
    runtime = runtimestring.split()
    try:
        minutes = int(runtime[0])*60 + int(runtime[2])
        return minutes
    except:
        return None

# %%
# convert runtime into integer in minutes
df['runtime (mins)'] = df['runtime (mins)'].map(lambda x: runtime_to_minutes(x))

# %%
df.head()
# Out:
#    domestic total gross             genre                  movie title rating  \
# 0            1768000000   Historical Epic           Gone with the Wind      G
# 1            1261768700    Sci-Fi Fantasy                    Star Wars     PG
# 2            1258951900           Musical           The Sound of Music      G
# 3            1099155300  Family Adventure  E.T.: The Extra-Terrestrial     PG
# 4            1134577600           Romance                      Titanic  PG-13
#
#   release date  runtime (mins)
# 0   1939-12-15             238
# 1   1977-05-25             121
# 2   1965-03-02             174
# 3   1982-06-11             117
# 4   1997-12-19             194

# %%
# Awesome! Now we have all our data in one place, in the desired format. 
# Now we get to actually have fun with our data! 
# There are many questions I want to ask about the most highly grossed movies.

# %%
# With the inflation adjuster in mind, which decade has produced the most high-grossing movies?
df.sort_values(by='release date').groupby(df['release date'].map(lambda x: int(x.year/10)*10)).count()
# Out:
#               domestic total gross  genre  movie title  rating  release date  \
# release date
# 1920                             1      1            1       1             1
# 1930                             2      2            2       2             2
# 1940                             7      7            7       7             7
# 1950                            13     13           13      13            13
# 1960                            19     19           19      19            19
# 1970                            26     26           26      26            26
# 1980                            25     25           25      25            25
# 1990                            32     32           32      32            32
# 2000                            42     42           42      42            42
# 2010                            33     33           33      33            33
#
#               runtime (mins)
# release date
# 1920                       1
# 1930                       2
# 1940                       7
# 1950                      13
# 1960                      19
# 1970                      26
# 1980                      25
# 1990                      32
# 2000                      42
# 2010                      33

# %%
# What is the average 
df.groupby('rating').median().sort_values('domestic total gross')
# Out:
#          domestic total gross  runtime (mins)
# rating
# R                 408598050.0           122.0
# PG-13             424230800.0           133.0
# PG                425264300.0           115.0
# G                 476258700.0            94.0
# Unrated           486200000.0           135.0
# M                 500452400.0           109.5
# GP                602437800.0           104.0

# %%
df[df.genre.str.contains('Animation')].sort_values('domestic total gross', ascending=False)
# Out:
#      domestic total gross      genre                      movie title rating  \
# 9               684844800  Animation  Snow White and the Seven Dwarfs      G
# 22              660693100  Animation                         Fantasia      G
# 18              659679500  Animation                    The Lion King      G
# 34              628090200  Animation                          Shrek 2     PG
# 32              606428700  Animation                  Sleeping Beauty      G
# 54              498023300  Animation                     Finding Nemo      G
# 11              497243800  Animation                   101 Dalmatians      G
# 72              496437500  Animation                     Finding Dory     PG
# 31              496314400  Animation                  The Jungle Book      G
# 40              488985200  Animation                        Pinocchio      G
# 95              463590300  Animation                          Aladdin      G
# 96              461464500  Animation                      Toy Story 3      G
# 107             433522600  Animation                           Frozen     PG
# 115             422874800  Animation                      Toy Story 2      G
# 116             418049200  Animation                            Shrek     PG
# 117             414657600  Animation                  Shrek the Third     PG
# 118             414543800  Animation                  Despicable Me 2     PG
# 106             398578900  Animation                   Monsters, Inc.      G
# 139             387796000  Animation                        Toy Story      G
# 144             382540500  Animation          The Secret Life of Pets     PG
# 146             381769500  Animation                       Inside Out     PG
# 160             371544800  Animation                  The Incredibles     PG
# 170             359913900  Animation                          Minions     PG
# 183             350117900  Animation                         Zootopia     PG
# 188             347180200  Animation                               Up     PG
# 75              335850400  Animation               Lady and the Tramp      G
# 128             309096900  Animation             Beauty and the Beast      G
# 126             288098500  Animation                        Peter Pan      G
# 57              166792500  Animation                       Cinderella      G
# 49               98222200  Animation                            Bambi      G
#
#     release date  runtime (mins)
# 9     1937-12-21              83
# 22    1941-01-29             120
# 18    1994-06-15              89
# 34    2004-05-19              93
# 32    1959-01-29              75
# 54    2003-05-30             104
# 11    1961-01-25              79
# 72    2016-06-17             103
# 31    1967-10-18              78
# 40    1940-02-09              88
# 95    1992-11-13              90
# 96    2010-06-18             103
# 107   2013-11-22             108
# 115   1999-11-19              92
# 116   2001-05-16              90
# 117   2007-05-18              92
# 118   2013-07-03              98
# 106   2001-11-02              90
# 139   1995-11-22              81
# 144   2016-07-08              90
# 146   2015-06-19              94
# 160   2004-11-05             115
# 170   2015-07-10              91
# 183   2016-03-04             108
# 188   2009-05-29              96
# 75    1955-06-22              75
# 128   1991-11-15              84
# 126   1953-02-05              76
# 57    1950-03-04              74
# 49    1942-08-21              69

# %% [markdown]
# ### TODO
#
# Some closing remarks!!

# %%
df.rating.value_counts()
# Out:
# PG-13      67
# PG         63
# G          31
# R          22
# Unrated    11
# GP          4
# M           2
# Name: rating, dtype: int64
